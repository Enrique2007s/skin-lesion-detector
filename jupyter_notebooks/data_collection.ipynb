# %% [markdown]
# #((Data Cleaning))**

# %% [markdown]
# ## Objectives
#
# * "Here, we will check all the images and make sure we dont have any data represented as text or any corrupted files"
#
# ## Inputs
#
# * inputs/skin_cancer_dataset/test/benign
# * inputs/skin_cancer_dataset/test/malignant
# * inputs/skin_cancer_dataset/train/benign
# * inputs/skin_cancer_dataset/train/malignant
#
# ## Outputs
#
# No files will be placed in outputs, however, we will be forming the train, validation, and test folders under inputs/skin_cancer_datasets
#
# ## Additional Comments
#
# No additional comments

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/skin-lesion-detector/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/skin-lesion-detector'

# %% [markdown]
# # Installing libraries

# %% [markdown]
# First, we will get our libraries installed

# %%
# %pip install -r/workspaces/skin-lesion-detector/requirements.txt
# Out:
# Requirement already satisfied: joblib==1.5.3 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: keras==3.15.1 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (3.15.1)
# Requirement already satisfied: matplotlib==3.11.1 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (3.11.1)
# Requirement already satisfied: numpy==2.5.2 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 5)) (2.5.2)
# Requirement already satisfied: pandas==2.2.3 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: pillow==12.3.0 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 7)) (12.3.0)
# Requirement already satisfied: plotly==6.9.0 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 8)) (6.9.0)
# Requirement already satisfied: scikit-learn==1.9.0 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: seaborn==0.13.2 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 10)) (0.13.2)
# Requirement already satisfied: tensorflow==2.21.0 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (2.21.0)
# Requirement already satisfied: streamlit==0.85.0 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (0.85.0)
# Requirement already satisfied: altair<5 in /home/cistudent/.local/lib/python3.12/site-packages (from -r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (4.2.2)
# Requirement already satisfied: absl-py in /home/cistudent/.local/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: rich in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (13.9.4)
# Requirement already satisfied: namex in /home/cistudent/.local/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: h5py in /home/cistudent/.local/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: optree in /home/cistudent/.local/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (0.20.0)
# Requirement already satisfied: ml-dtypes in /home/cistudent/.local/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: packaging in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cistudent/.local/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/cistudent/.local/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /home/cistudent/.local/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cistudent/.local/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: pyparsing>=3 in /home/cistudent/.local/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from matplotlib==3.11.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/cistudent/.local/lib/python3.12/site-packages (from pandas==2.2.3->-r /workspaces/skin-lesion-detector/requirements.txt (line 6)) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cistudent/.local/lib/python3.12/site-packages (from pandas==2.2.3->-r /workspaces/skin-lesion-detector/requirements.txt (line 6)) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in /home/cistudent/.local/lib/python3.12/site-packages (from plotly==6.9.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 8)) (2.25.0)
# Requirement already satisfied: scipy>=1.10.0 in /home/cistudent/.local/lib/python3.12/site-packages (from scikit-learn==1.9.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 9)) (1.18.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/cistudent/.local/lib/python3.12/site-packages (from scikit-learn==1.9.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (7.36.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: setuptools in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/cistudent/.local/lib/python3.12/site-packages (from tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (1.83.1)
# Requirement already satisfied: astor in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (0.8.1)
# Requirement already satisfied: attrs in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (24.3.0)
# Requirement already satisfied: base58 in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: blinker in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: cachetools>=4.0 in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (7.1.8)
# Requirement already satisfied: click<8.0,>=7.0 in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (7.1.2)
# Requirement already satisfied: pyarrow in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (25.0.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (0.9.3)
# Requirement already satisfied: toml in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (6.4.2)
# Requirement already satisfied: tzlocal in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (5.4.4)
# Requirement already satisfied: validators in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (0.35.0)
# Requirement already satisfied: gitpython in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (3.1.61)
# Requirement already satisfied: watchdog in /home/cistudent/.local/lib/python3.12/site-packages (from streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: entrypoints in /home/cistudent/.local/lib/python3.12/site-packages (from altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jinja2 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (4.23.0)
# Requirement already satisfied: toolz in /home/cistudent/.local/lib/python3.12/site-packages (from altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (0.45.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=3.0->altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=3.0->altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jsonschema>=3.0->altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from jinja2->altair<5->-r /workspaces/skin-lesion-detector/requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.21.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 11)) (2024.12.14)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/cistudent/.local/lib/python3.12/site-packages (from gitpython->streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (4.0.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from rich->keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from rich->keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/cistudent/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit==0.85.0->-r /workspaces/skin-lesion-detector/requirements.txt (line 12)) (5.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.15.1->-r /workspaces/skin-lesion-detector/requirements.txt (line 3)) (0.1.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now lets get kaggle and our OS so we can get our dataset in this notebook

# %%
# %pip install kaggle==1.5.12
# Out:
# Requirement already satisfied: kaggle==1.5.12 in /home/cistudent/.local/lib/python3.12/site-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from kaggle==1.5.12) (1.17.0)
# Requirement already satisfied: certifi in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from kaggle==1.5.12) (2024.12.14)
# Requirement already satisfied: python-dateutil in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from kaggle==1.5.12) (2.9.0.post0)
# Requirement already satisfied: requests in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from kaggle==1.5.12) (2.32.3)
# Requirement already satisfied: tqdm in /home/cistudent/.local/lib/python3.12/site-packages (from kaggle==1.5.12) (4.70.0)
# Requirement already satisfied: python-slugify in /home/cistudent/.local/lib/python3.12/site-packages (from kaggle==1.5.12) (8.0.4)
# Requirement already satisfied: urllib3 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from kaggle==1.5.12) (2.2.3)
# Requirement already satisfied: text-unidecode>=1.3 in /home/cistudent/.local/lib/python3.12/site-packages (from python-slugify->kaggle==1.5.12) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests->kaggle==1.5.12) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/cistudent/.pyenv/versions/3.12.1/lib/python3.12/site-packages (from requests->kaggle==1.5.12) (3.10)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We run this to change the kaggle config. directory to the current working directory and set permissios for the kaggle auth JSON

# %%
repo_root = "/workspaces/skin-lesion-detector"
os.chdir(repo_root)
os.environ["KAGGLE_CONFIG_DIR"] = repo_root

print(os.getcwd())
print(os.path.exists(os.path.join(repo_root, "kaggle.json")))
# Out:
# /workspaces/skin-lesion-detector
# True

# %% [markdown]
# Download the Kaggle Dataset

# %%
KaggleDatasetPath = "hasnainjaved/melanoma-skin-cancer-dataset-of-10000-images"
DestinationFolder = "inputs/skin_cancer_dataset"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /workspaces/skin-lesion-detector/kaggle.json'
# melanoma-skin-cancer-dataset-of-10000-images.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# Now we will unzip the file

# %%
import zipfile
with zipfile.ZipFile(DestinationFolder + "/melanoma-skin-cancer-dataset-of-10000-images.zip", 'r') as zip_ref:
    zip_ref.extractall(DestinationFolder)

# %% [markdown]
# and now we remove the zip file

# %%
os.remove(DestinationFolder + '/melanoma-skin-cancer-dataset-of-10000-images.zip')

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions and Next Steps in data cleaning

# %% [markdown]
# Section 2 content

# %% [markdown]
# We have now downloaded the Kaggle dataset and unzipped the files
#
# Next, we will clean the data so we don't have any corrupt or text files when training our mode. Then, we will separate the files into train, validation, and test sets
#
# Also, since we only obtained the inputs folder, there is no need to put outputs since we still have not obtained any outputs for what will be displayed in the dashboard
#
# Lastly, do the following commands int he terminal to save the files
#
# git add .
#
# git commit -m "add the message you want to commit"
#
# git push

# %% [markdown]
# ---
