# %% [markdown]
# # **((Feature Engineering))**

# %% [markdown]
# ## Why not?
#
# * "We will not be conducting feature engineering, as previously seen, all images are of the same size and colour. Also, Convolutional Neural Networks do not require manual feature engineering because it automatically learns hierarchical features from the data
